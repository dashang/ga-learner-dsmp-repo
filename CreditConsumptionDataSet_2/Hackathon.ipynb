# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dashang\\Downloads\\CreditConsumptionDataSet_2'

# %%
traindt = pd.read_csv("Train.csv")

# %%
y_actual_df = pd.read_csv('Test.csv')

# %%
y_actual_df.shape
# Out:
# (5000, 43)

# %%
traindt.shape
# Out:
# (15000, 44)

# %% [markdown]
# ## Check for Null

# %%
traindt.isna().sum()
# Out:
# ID                       0
# account_type             0
# gender                   0
# age                      0
# region_code              0
# cc_cons_apr              0
# dc_cons_apr              0
# cc_cons_may              0
# dc_cons_may              0
# cc_cons_jun              0
# dc_cons_jun              0
# cc_count_apr             0
# cc_count_may             0
# cc_count_jun             0
# dc_count_apr             0
# dc_count_may             0
# dc_count_jun             0
# card_lim                 0
# personal_loan_active     0
# vehicle_loan_active      0
# personal_loan_closed     0
# vehicle_loan_closed      0
# investment_1             0
# investment_2             0
# investment_3             0
# investment_4             0
# debit_amount_apr         0
# credit_amount_apr        0
# debit_count_apr          0
# credit_count_apr         0
# max_credit_amount_apr    0
# debit_amount_may         0
# credit_amount_may        0
# credit_count_may         0
# ...

# %%
traindt.head(5)
# Out:
#       ID account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0  12554      current      M   35          708     24893.00       378.00
# 1  17645      current      M   35          123     18941.62       966.00
# 2   7604      current      M   55          802      5678.87      2724.00
# 3   1590      current      F   29          867     30489.50      1236.00
# 4  16556      current      M   34          802      7441.40      6906.04
#
#    cc_cons_may  dc_cons_may  cc_cons_jun  ...  debit_count_may  \
# 0     10288.00     29664.00     16291.40  ...             40.0
# 1     20672.00       287.00      4217.00  ...             78.0
# 2      1964.50      3933.11     23956.25  ...             82.0
# 3     12609.88      9138.14     17521.00  ...             38.0
# 4      4364.00      1939.00      2121.00  ...             50.0
#
#    max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# 0                24563.0          30051.32            12761.0
# ...

# %% [markdown]
# <h3>
#     Null Investment to 0

# %%
traindt["investment_1"]=traindt["investment_1"].fillna(0)
traindt["investment_2"]=traindt["investment_2"].fillna(0)
traindt["investment_3"]=traindt["investment_3"].fillna(0)
traindt["investment_4"]=traindt["investment_4"].fillna(0)

# %%
traindt.drop(["personal_loan_active","vehicle_loan_active","personal_loan_closed","vehicle_loan_closed","loan_enq"],axis=1,inplace=True)

# %%
traindt.columns
# Out:
# Index(['ID', 'account_type', 'gender', 'age', 'region_code', 'cc_cons_apr',
#        'dc_cons_apr', 'cc_cons_may', 'dc_cons_may', 'cc_cons_jun',
#        'dc_cons_jun', 'cc_count_apr', 'cc_count_may', 'cc_count_jun',
#        'dc_count_apr', 'dc_count_may', 'dc_count_jun', 'card_lim',
#        'investment_1', 'investment_2', 'investment_3', 'investment_4',
#        'debit_amount_apr', 'credit_amount_apr', 'debit_count_apr',
#        'credit_count_apr', 'max_credit_amount_apr', 'debit_amount_may',
#        'credit_amount_may', 'credit_count_may', 'debit_count_may',
#        'max_credit_amount_may', 'debit_amount_jun', 'credit_amount_jun',
#        'credit_count_jun', 'debit_count_jun', 'max_credit_amount_jun',
#        'emi_active', 'cc_cons'],
#       dtype='object')

# %%
traindt["dc_cons_apr"]=traindt["dc_cons_apr"].fillna(0)
traindt["dc_cons_may"]=traindt["dc_cons_may"].fillna(0)
traindt["dc_cons_jun"]=traindt["dc_cons_jun"].fillna(0)
traindt["cc_count_apr"]=traindt["cc_count_apr"].fillna(0)
traindt["cc_count_may"]=traindt["cc_count_may"].fillna(0)
traindt["cc_count_jun"]=traindt["cc_count_jun"].fillna(0)
traindt["dc_count_apr"]=traindt["dc_count_apr"].fillna(0)
traindt["dc_count_may"]=traindt["dc_count_may"].fillna(0)
traindt["dc_count_jun"]=traindt["dc_count_jun"].fillna(0)

# %%
traindt["card_lim"]=traindt["card_lim"].fillna(0)

traindt["debit_amount_apr"]=traindt["debit_amount_apr"].fillna(0)
traindt["credit_amount_apr"]=traindt["credit_amount_apr"].fillna(0)
traindt["debit_count_apr"]=traindt["debit_count_apr"].fillna(0)
traindt["credit_count_apr"]=traindt["credit_count_apr"].fillna(0)
traindt["max_credit_amount_apr"]=traindt["max_credit_amount_apr"].fillna(0)
traindt["debit_amount_may"]=traindt["debit_amount_may"].fillna(0)
traindt["credit_amount_may"]=traindt["credit_amount_may"].fillna(0)
traindt["credit_count_may"]=traindt["credit_count_may"].fillna(0)
traindt["debit_count_may"]=traindt["debit_count_may"].fillna(0)
traindt["max_credit_amount_may"]=traindt["max_credit_amount_may"].fillna(0)
traindt["debit_amount_jun"]=traindt["debit_amount_jun"].fillna(0)
traindt["credit_amount_jun"]=traindt["credit_amount_jun"].fillna(0)
traindt["credit_count_jun"]=traindt["credit_count_jun"].fillna(0)
traindt["debit_count_jun"]=traindt["debit_count_jun"].fillna(0)
traindt["max_credit_amount_jun"]=traindt["max_credit_amount_jun"].fillna(0)

# %%
(traindt.isna().sum() / traindt.shape[0]) * 100
# Out:
# ID                       0.0
# account_type             0.0
# gender                   0.0
# age                      0.0
# region_code              0.0
# cc_cons_apr              0.0
# dc_cons_apr              0.0
# cc_cons_may              0.0
# dc_cons_may              0.0
# cc_cons_jun              0.0
# dc_cons_jun              0.0
# cc_count_apr             0.0
# cc_count_may             0.0
# cc_count_jun             0.0
# dc_count_apr             0.0
# dc_count_may             0.0
# dc_count_jun             0.0
# card_lim                 0.0
# investment_1             0.0
# investment_2             0.0
# investment_3             0.0
# investment_4             0.0
# debit_amount_apr         0.0
# credit_amount_apr        0.0
# debit_count_apr          0.0
# credit_count_apr         0.0
# max_credit_amount_apr    0.0
# debit_amount_may         0.0
# credit_amount_may        0.0
# credit_count_may         0.0
# debit_count_may          0.0
# max_credit_amount_may    0.0
# ...

# %%
traindt.dtypes
# Out:
# ID                         int64
# account_type              object
# gender                    object
# age                        int64
# region_code                int64
# cc_cons_apr              float64
# dc_cons_apr              float64
# cc_cons_may              float64
# dc_cons_may              float64
# cc_cons_jun              float64
# dc_cons_jun              float64
# cc_count_apr             float64
# cc_count_may             float64
# cc_count_jun             float64
# dc_count_apr             float64
# dc_count_may             float64
# dc_count_jun             float64
# card_lim                 float64
# investment_1             float64
# investment_2             float64
# investment_3             float64
# investment_4             float64
# debit_amount_apr         float64
# credit_amount_apr        float64
# debit_count_apr          float64
# credit_count_apr         float64
# max_credit_amount_apr    float64
# debit_amount_may         float64
# ...

# %%
y_actual_df.dtypes
# Out:
# ID                         int64
# account_type              object
# gender                    object
# age                        int64
# region_code                int64
# cc_cons_apr              float64
# dc_cons_apr              float64
# cc_cons_may              float64
# dc_cons_may              float64
# cc_cons_jun              float64
# dc_cons_jun              float64
# cc_count_apr             float64
# cc_count_may             float64
# cc_count_jun             float64
# dc_count_apr             float64
# dc_count_may             float64
# dc_count_jun             float64
# card_lim                 float64
# personal_loan_active     float64
# vehicle_loan_active      float64
# personal_loan_closed     float64
# vehicle_loan_closed      float64
# investment_1             float64
# investment_2             float64
# investment_3             float64
# investment_4             float64
# debit_amount_apr         float64
# credit_amount_apr        float64
# ...

# %%
traindt
# Out:
#           ID account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0      12554      current      M   35          708     24893.00       378.00
# 1      17645      current      M   35          123     18941.62       966.00
# 2       7604      current      M   55          802      5678.87      2724.00
# 3       1590      current      F   29          867     30489.50      1236.00
# 4      16556      current      M   34          802      7441.40      6906.04
# ...      ...          ...    ...  ...          ...          ...          ...
# 14995   6995      current      F   53          653     10443.76      1218.85
# 14996  10376      current      M   44          535     29890.33      6308.00
# 14997   2181      current      M   37          464      4148.98       948.74
# 14998  18417      current      M  220          536    115574.00      7191.05
# 14999   4547      current      M   66          269      7375.67       306.80
#
# ...

# %% [markdown]
# <h3> Dummies for Account type

# %%
Accountdf = pd.get_dummies(traindt['account_type'], prefix = 'account_')
Accountdf.dtypes
# Out:
# account__current    uint8
# account__saving     uint8
# dtype: object

# %%
merge_df = pd.concat([traindt,pd.DataFrame(Accountdf)],axis=1)

# %%
genderdf = pd.get_dummies(traindt['gender'], prefix = 'gender_')
print(genderdf.dtypes)
merge_df = pd.concat([merge_df,pd.DataFrame(genderdf)],axis=1)
# Out:
# gender__F    uint8
# gender__M    uint8
# dtype: object

# %%
# y_actual_df

testAccountdf = pd.get_dummies(y_actual_df['account_type'], prefix = 'account_')
testmerge_df = pd.concat([y_actual_df,pd.DataFrame(testAccountdf)],axis=1)
testgenderdf = pd.get_dummies(y_actual_df['gender'], prefix = 'gender_')
print(testgenderdf.dtypes)
testmerge_df = pd.concat([testmerge_df,pd.DataFrame(testgenderdf)],axis=1)
# Out:
# gender__F    uint8
# gender__M    uint8
# dtype: object

# %%
testRemoved_Cat_df = testmerge_df.drop(['account_type','gender'],axis=1)

# %%
Removed_Cat_df = merge_df.drop(['account_type','gender'],axis=1)

# %%
Removed_Cat_df.head(5)
# Out:
#       ID  age  region_code  cc_cons_apr  dc_cons_apr  cc_cons_may  \
# 0  12554   35          708     24893.00       378.00     10288.00
# 1  17645   35          123     18941.62       966.00     20672.00
# 2   7604   55          802      5678.87      2724.00      1964.50
# 3   1590   29          867     30489.50      1236.00     12609.88
# 4  16556   34          802      7441.40      6906.04      4364.00
#
#    dc_cons_may  cc_cons_jun  dc_cons_jun  cc_count_apr  ...  \
# 0     29664.00     16291.40     11432.00           2.0  ...
# 1       287.00      4217.00       885.00           1.0  ...
# 2      3933.11     23956.25      5168.00          43.0  ...
# 3      9138.14     17521.00     13650.30          53.0  ...
# 4      1939.00      2121.00      6829.18          67.0  ...
#
#    credit_amount_jun  credit_count_jun  debit_count_jun  \
# 0            12761.0               2.0             65.0
# 1            76206.0              21.0             63.0
# ...

# %%
Removed_Cat_df.dtypes
# Out:
# ID                         int64
# age                        int64
# region_code                int64
# cc_cons_apr              float64
# dc_cons_apr              float64
# cc_cons_may              float64
# dc_cons_may              float64
# cc_cons_jun              float64
# dc_cons_jun              float64
# cc_count_apr             float64
# cc_count_may             float64
# cc_count_jun             float64
# dc_count_apr             float64
# dc_count_may             float64
# dc_count_jun             float64
# card_lim                 float64
# personal_loan_active     float64
# vehicle_loan_active      float64
# personal_loan_closed     float64
# vehicle_loan_closed      float64
# investment_1             float64
# investment_2             float64
# investment_3             float64
# investment_4             float64
# debit_amount_apr         float64
# credit_amount_apr        float64
# debit_count_apr          float64
# credit_count_apr         float64
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
stanScaler = StandardScaler()

# %%
removed_cat_df_col_list = Removed_Cat_df.columns.to_list()

# %%
stanScaler.fit(Removed_Cat_df[removed_cat_df_col_list])
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
Removed_Cat_df[removed_cat_df_col_list] = stanScaler.transform(Removed_Cat_df[removed_cat_df_col_list])

# %%
Removed_Cat_df
# Out:
#              ID       age  region_code  cc_cons_apr  dc_cons_apr  cc_cons_may  \
# 0      0.437820 -0.417560     0.497987     0.275364    -0.527540    -0.223543
# 1      1.321647 -0.417560    -2.160439     0.039077    -0.487736     0.160198
# 2     -0.421528  0.235357     0.925153    -0.487492    -0.368731    -0.531138
# 3     -1.465592 -0.613436     1.220534     0.497561    -0.469459    -0.137738
# 4      1.132590 -0.450206     0.925153    -0.417515    -0.085636    -0.442464
# ...         ...       ...          ...          ...          ...          ...
# 14995 -0.527254  0.170065     0.248049    -0.298313    -0.470620    -0.335729
# 14996  0.059707 -0.123747    -0.288180     0.473772    -0.126119    -0.011513
# 14997 -1.362992 -0.352269    -0.610827    -0.548233    -0.488904     0.111723
# 14998  1.455670  5.621926    -0.283636     3.875659    -0.066343     1.034890
# 14999 -0.952241  0.594462    -1.496969    -0.420125    -0.532359    -0.387198
#
# ...

# %%
# scaling for Test Data
print(testRemoved_Cat_df.dtypes)
testremoved_cat_df_col_list = testRemoved_Cat_df.columns.to_list()
print(testremoved_cat_df_col_list)
testRemoved_Cat_df[testremoved_cat_df_col_list] = stanScaler.transform(testRemoved_Cat_df[testremoved_cat_df_col_list])
# Out:
# ID                         int64
# age                        int64
# region_code                int64
# cc_cons_apr              float64
# dc_cons_apr              float64
# cc_cons_may              float64
# dc_cons_may              float64
# cc_cons_jun              float64
# dc_cons_jun              float64
# cc_count_apr             float64
# cc_count_may             float64
# cc_count_jun             float64
# dc_count_apr             float64
# dc_count_may             float64
# dc_count_jun             float64
# card_lim                 float64
# personal_loan_active     float64
# vehicle_loan_active      float64
# personal_loan_closed     float64
# vehicle_loan_closed      float64
# investment_1             float64
# investment_2             float64
# investment_3             float64
# investment_4             float64
# debit_amount_apr         float64
# credit_amount_apr        float64
# debit_count_apr          float64
# credit_count_apr         float64
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (12.0, 6.0)
prices = pd.DataFrame({"price":Removed_Cat_df["cc_cons"], "log(price + 1)":np.log1p(Removed_Cat_df["cc_cons"])})
prices.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AABE1A6908>,
# ...
#       dtype=object)

# %%
Removed_Cat_df.cc_cons = np.log1p(Removed_Cat_df["cc_cons"])

# %%
X= Removed_Cat_df.drop(["ID","cc_cons"],axis=1)
y=Removed_Cat_df.cc_cons

# %%
def rmsle(actual_column, predicted_column):
    sum=0.0
    for x,y in zip(real_column,predicted_column):
        if x<0 or y<0: #check for negative values. 
            continue
        p = np.log(y+1)
        r = np.log(x+1)
        sum = sum + (p - r)**2
    return (sum/len(predicted_column))**0.5

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.2, random_state=6)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import math

# %%
print(y_actual_df.dtypes)
print((y_actual_df.isna().sum() / y_actual_df.shape[0]) * 100)
testAccountdf = pd.get_dummies(y_actual_df['account_type'], prefix = 'account')
testAccountdf.dtypes
testmerge_df = pd.concat([y_actual_df,pd.DataFrame(testAccountdf)],axis=1)
testgenderdf = pd.get_dummies(y_actual_df['gender'], prefix = 'gender')
print(testgenderdf.dtypes)
testmerge_df = pd.concat([testmerge_df,pd.DataFrame(testgenderdf)],axis=1)
testloandf = pd.get_dummies(y_actual_df['loan_enq'], prefix = 'loanEnq')
print(testloandf.dtypes)
testmerge_df = pd.concat([testmerge_df,pd.DataFrame(testloandf)],axis=1)
testRemoved_Cat_df = testmerge_df.drop(['account_type','gender','loan_enq'],axis=1)
# Out:
# ID                         int64
# account_type              object
# gender                    object
# age                        int64
# region_code                int64
# cc_cons_apr              float64
# dc_cons_apr              float64
# cc_cons_may              float64
# dc_cons_may              float64
# cc_cons_jun              float64
# dc_cons_jun              float64
# cc_count_apr             float64
# cc_count_may             float64
# cc_count_jun             float64
# dc_count_apr             float64
# dc_count_may             float64
# dc_count_jun             float64
# card_lim                 float64
# personal_loan_active     float64
# vehicle_loan_active      float64
# personal_loan_closed     float64
# vehicle_loan_closed      float64
# investment_1             float64
# investment_2             float64
# investment_3             float64
# investment_4             float64
# debit_amount_apr         float64
# credit_amount_apr        float64
# ...

# %%
testRemoved_Cat_df
# Out:
#          ID  age  region_code  cc_cons_apr  dc_cons_apr  cc_cons_may  \
# 0     17591   37          575     2795.450      1290.00      6141.05
# 1     13541   33          394    29405.130      1640.00      1670.00
# 2     13431   53          324     5985.200      6189.00      2696.09
# 3      8687   33          370     2105.930     18225.00     34763.56
# 4     14727   62          505     3269.000      3532.00      3158.40
# ...     ...  ...          ...          ...          ...          ...
# 4995  12512   35          523     4641.500      5979.58      6008.61
# 4996  14224   53          723     4994.450      2805.37     23214.00
# 4997  18740   62          863     3262.145      2871.00      7335.25
# 4998  18134   34          882    12824.010      4866.00     12242.48
# 4999  12413   27          447    26218.000      6615.00      2832.00
#
#       dc_cons_may  cc_cons_jun  dc_cons_jun  cc_count_apr  ...  \
# 0          676.50      9146.10     15479.00           4.0  ...
# ...

# %%
def model_and_performance(model, model_name, train_x, train_y, test_x, test_y,y_actual):
    model.fit(train_x, train_y)
    train_pred = model.predict(train_x)
    test_pred = model.predict(test_x)
    actual_pred = model.predict(y_actual)
    
    print('MSE', mean_squared_error(train_y, train_pred), 'MAE', mean_absolute_error(train_y, train_pred), 
          'R2', r2_score(train_y, train_pred), 'RMSE', math.sqrt(mean_squared_error(train_y, train_pred)))
    
    print('MSE', mean_squared_error(test_y, test_pred), 'MAE', mean_absolute_error(test_y, test_pred), 
          'R2', r2_score(test_y, test_pred), math.sqrt(mean_squared_error(test_y, test_pred)))
    print('RMSLE Score: ',train_y,test_pred)
    pd.DataFrame(actual_pred, columns=['ID','cc_cons']).to_csv(''+model_name+'.csv')

# %%
model_and_performance(LinearRegression(), "Linear_Model", train_x, train_y, test_x, test_y,testRemoved_Cat_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-f58dc0af6149> in <module>
# ----> 1 model_and_performance(LinearRegression(), "Linear_Model", train_x, train_y, test_x, test_y,testRemoved_Cat_df)
#
# <ipython-input-48-9244c8876a84> in model_and_performance(model, model_name, train_x, train_y, test_x, test_y, y_actual)
#       3     train_pred = model.predict(train_x)
#       4     test_pred = model.predict(test_x)
# ----> 5     actual_pred = model.predict(y_actual)
#       6
#       7     print('MSE', mean_squared_error(train_y, train_pred), 'MAE', mean_absolute_error(train_y, train_pred),
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
# ...

# %% [markdown]
# <h3> L1 regularization

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=6)

# %%
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV

# %%
# Create linear regression object
Ls = LassoCV()

# Train the model using the training sets
Ls.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# LassoCV(alphas=None, copy_X=True, cv='warn', eps=0.001, fit_intercept=True,
#         max_iter=1000, n_alphas=100, n_jobs=None, normalize=False,
#         positive=False, precompute='auto', random_state=None,
#         selection='cyclic', tol=0.0001, verbose=False)

# %%
maxcoef = np.argsort(-np.abs(Ls.coef_))
coef = Ls.coef_[maxcoef]
for i in range(0, 5):
    print("{:.<025} {:< 010.4e}".format(X.columns[maxcoef[i]], coef[i]))
# Out:
# cc_cons_may..............  5.3008e-18
# age...................... -0.0000e+00
# credit_amount_apr........  0.0000e+00
# debit_count_apr.......... -0.0000e+00
# credit_count_apr......... -0.0000e+00

# %%
# Create linear regression object
Rr = RidgeCV()

# Train the model using the training sets
Rr.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=None, fit_intercept=True,
#         gcv_mode=None, normalize=False, scoring=None, store_cv_values=False)

# %%
maxcoef = np.argsort(-np.abs(Rr.coef_))
coef = Rr.coef_[maxcoef]
for i in range(0, 5):
    print("{:.<025} {:< 010.4e}".format(X.columns[maxcoef[i]], coef[i]))
# Out:
# max_credit_amount_may....  1.4872e-02
# cc_cons_may..............  1.3909e-02
# cc_count_may.............  1.3183e-02
# region_code.............. -1.2499e-02
# cc_count_apr............. -1.0793e-02

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %%
model = [Ls, Rr]
M = len(model)
CV = 5
score = np.empty((M, CV))
for i in range(0, M):
    score[i, :] = cross_val_score(model[i], X_train, y_train, cv=CV)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
# ...

# %%
print(score.mean(axis=1))
# Out:
# [-0.00047149 -0.0039004 ]

# %% [markdown]
# <h3> Random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators=10, random_state=0)
regressor.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %%
X=X.drop(X.tail(1).index)

# %%
#X_grid = np.arange(min(X),max(X),0.01)
#X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X,y,color='red')
plt.plot(X,regressor.predict(X),color='blue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-846c61e5c6b3> in <module>
#       1 #X_grid = np.arange(min(X),max(X),0.01)
#       2 #X_grid = X_grid.reshape((len(X_grid),1))
# ----> 3 plt.scatter(X,y,color='red')
#       4 plt.plot(X,regressor.predict(X),color='blue')
#       5 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dashang\\Downloads\\CreditConsumptionDataSet_2'

# %%
sub= pd.read_excel('Linear_Model.csv')
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-58-4b829abfadc3> in <module>
# ----> 1 sub= pd.read_excel('Linear_Model.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# ...
